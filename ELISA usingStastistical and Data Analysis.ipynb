# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# !mamba install -qy -c conda-forge pandas==0.25.1 matplotlib seaborn==0.9.0
# Out:
# /bin/bash: line 1: mamba: command not found

# %%
import openpyxl
from datetime import datetime

# %%
df = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/data-science-in-health-care-basic-statistical-analysis/COVID_19.xlsx',
    'Sheet1')

# %%
df
# Out:
#                    Date time    Age          Gender                 Region  \
# 0    2020-09-20 11:23:15.000  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 1    2020-09-20 11:23:15.000  23-40  Female (Жінка)    Ukraine, Chernivtsi
# 2    2020-09-20 11:23:15.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3    2020-09-20 11:23:15.000  40-65  Male (Чоловік)    Ukraine, Chernivtsi
# 4    2020-09-20 11:23:15.000  16-22  Male (Чоловік)  Ukraine, Lviv (Львів)
# ...                      ...    ...             ...                    ...
# 3303 2021-03-02 09:56:35.956  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3304 2021-03-02 10:10:18.976  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3305 2021-03-04 11:03:43.786  40-65  Male (Чоловік)  Ukraine, Lviv (Львів)
# 3306 2021-03-04 11:04:30.416  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3307 2021-04-05 03:18:16.644  16-22  Female (Жінка)  Ukraine, Lviv (Львів)
#
#      Do you smoke? Have you had Covid`19 this year?  \
# 0               No                  Maybe (можливо)
# 1               No                              Yes
# 2               No                  Maybe (можливо)
# 3               No                               No
# 4               No                              Yes
# ...            ...                              ...
# 3303            No                  Maybe (можливо)
# 3304            No                  Maybe (можливо)
# 3305            No                  Maybe (можливо)
# 3306            No                  Maybe (можливо)
# 3307           Yes                              Yes
#
#                        IgM level                           IgG level  \
# 0     <0.9 (negative/негативний)  0.9-1.1 (indefinable/невизначений)
# 1     >1.1 (positive/позитивний)  0.9-1.1 (indefinable/невизначений)
# 2     <0.9 (negative/негативний)          <0.9 (negative/негативний)
# 3     <0.9 (negative/негативний)          <0.9 (negative/негативний)
# 4     >1.1 (positive/позитивний)          <0.9 (negative/негативний)
# ...                          ...                                 ...
# 3303                         NaN                                 NaN
# 3304                         NaN                                 NaN
# 3305                         NaN                                 NaN
# 3306                         NaN                                 NaN
# 3307  <0.9 (negative/негативний)          >1.1 (positive/позитивний)
#
#       Blood group Do you vaccinated influenza?  \
# 0             2.0                          Yes
# 1             2.0                           No
# 2             2.0                           No
# 3             2.0                           No
# 4             1.0                           No
# ...           ...                          ...
# 3303          2.0                          Yes
# 3304          2.0                          Yes
# 3305          1.0                           No
# 3306          2.0                           No
# 3307          2.0                           No
#
#      Do you vaccinated tuberculosis? Have you had influenza this year?  \
# 0                                Yes                                No
# 1                                Yes                                No
# 2                                Yes                               Yes
# 3                                Yes                                No
# 4                                Yes                               Yes
# ...                              ...                               ...
# 3303                             Yes                   Maybe (можливо)
# 3304                             Yes                   Maybe (можливо)
# 3305                             Yes                   Maybe (можливо)
# 3306                             Yes                   Maybe (можливо)
# 3307                             Yes                                No
#
#      Have you had tuberculosis this year?   Maximum body temperature
# 0                                       No                      38.1
# 1                                       No                      37.0
# 2                                       No                      37.8
# 3                                       No                       NaN
# 4                                       No                      37.4
# ...                                    ...                       ...
# 3303                                    No                      37.3
# 3304                                    No                      37.4
# 3305                                    No                      37.7
# 3306                                    No                      38.0
# 3307                                    No                      37.4
#
# [3308 rows x 14 columns]

# %%
def parse(x):
    y = x.split()
    t = y[1][:8]
    z=y[0] + " " + t
    d = datetime.strptime(z, '%Y-%m-%d %H:%M:%S')
    return d

# %%
df
# Out:
#                    Date time    Age          Gender                 Region  \
# 0    2020-09-20 11:23:15.000  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 1    2020-09-20 11:23:15.000  23-40  Female (Жінка)    Ukraine, Chernivtsi
# 2    2020-09-20 11:23:15.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3    2020-09-20 11:23:15.000  40-65  Male (Чоловік)    Ukraine, Chernivtsi
# 4    2020-09-20 11:23:15.000  16-22  Male (Чоловік)  Ukraine, Lviv (Львів)
# ...                      ...    ...             ...                    ...
# 3303 2021-03-02 09:56:35.956  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3304 2021-03-02 10:10:18.976  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3305 2021-03-04 11:03:43.786  40-65  Male (Чоловік)  Ukraine, Lviv (Львів)
# 3306 2021-03-04 11:04:30.416  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3307 2021-04-05 03:18:16.644  16-22  Female (Жінка)  Ukraine, Lviv (Львів)
#
#      Do you smoke? Have you had Covid`19 this year?  \
# 0               No                  Maybe (можливо)
# 1               No                              Yes
# 2               No                  Maybe (можливо)
# 3               No                               No
# 4               No                              Yes
# ...            ...                              ...
# 3303            No                  Maybe (можливо)
# 3304            No                  Maybe (можливо)
# 3305            No                  Maybe (можливо)
# 3306            No                  Maybe (можливо)
# 3307           Yes                              Yes
#
#                        IgM level                           IgG level  \
# 0     <0.9 (negative/негативний)  0.9-1.1 (indefinable/невизначений)
# 1     >1.1 (positive/позитивний)  0.9-1.1 (indefinable/невизначений)
# 2     <0.9 (negative/негативний)          <0.9 (negative/негативний)
# 3     <0.9 (negative/негативний)          <0.9 (negative/негативний)
# 4     >1.1 (positive/позитивний)          <0.9 (negative/негативний)
# ...                          ...                                 ...
# 3303                         NaN                                 NaN
# 3304                         NaN                                 NaN
# 3305                         NaN                                 NaN
# 3306                         NaN                                 NaN
# 3307  <0.9 (negative/негативний)          >1.1 (positive/позитивний)
#
#       Blood group Do you vaccinated influenza?  \
# 0             2.0                          Yes
# 1             2.0                           No
# 2             2.0                           No
# 3             2.0                           No
# 4             1.0                           No
# ...           ...                          ...
# 3303          2.0                          Yes
# 3304          2.0                          Yes
# 3305          1.0                           No
# 3306          2.0                           No
# 3307          2.0                           No
#
#      Do you vaccinated tuberculosis? Have you had influenza this year?  \
# 0                                Yes                                No
# 1                                Yes                                No
# 2                                Yes                               Yes
# 3                                Yes                                No
# 4                                Yes                               Yes
# ...                              ...                               ...
# 3303                             Yes                   Maybe (можливо)
# 3304                             Yes                   Maybe (можливо)
# 3305                             Yes                   Maybe (можливо)
# 3306                             Yes                   Maybe (можливо)
# 3307                             Yes                                No
#
#      Have you had tuberculosis this year?   Maximum body temperature
# 0                                       No                      38.1
# 1                                       No                      37.0
# 2                                       No                      37.8
# 3                                       No                       NaN
# 4                                       No                      37.4
# ...                                    ...                       ...
# 3303                                    No                      37.3
# 3304                                    No                      37.4
# 3305                                    No                      37.7
# 3306                                    No                      38.0
# 3307                                    No                      37.4
#
# [3308 rows x 14 columns]

# %%
f = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/data-science-in-health-care-basic-statistical-analysis/COVID_19.xlsx',
    'Sheet1',
    na_values="NaN",
    parse_dates=['Date time'],
    index_col=0,
    date_parser=parse)
# Out:
# /tmp/ipython-input-19-1437461509.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   f = pd.read_excel(

# %%
df = df.dropna(subset=['Gender'])

# %%
d = {'No' : False, 'Yes' : True}
c = 'Do you vaccinated influenza?'
df.loc[:, c] = df[c].map(d)

# %%
df
# Out:
#                    Date time    Age          Gender                 Region  \
# 0    2020-09-20 11:23:15.000  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 1    2020-09-20 11:23:15.000  23-40  Female (Жінка)    Ukraine, Chernivtsi
# 2    2020-09-20 11:23:15.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3    2020-09-20 11:23:15.000  40-65  Male (Чоловік)    Ukraine, Chernivtsi
# 4    2020-09-20 11:23:15.000  16-22  Male (Чоловік)  Ukraine, Lviv (Львів)
# ...                      ...    ...             ...                    ...
# 3303 2021-03-02 09:56:35.956  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3304 2021-03-02 10:10:18.976  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3305 2021-03-04 11:03:43.786  40-65  Male (Чоловік)  Ukraine, Lviv (Львів)
# 3306 2021-03-04 11:04:30.416  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3307 2021-04-05 03:18:16.644  16-22  Female (Жінка)  Ukraine, Lviv (Львів)
#
#      Do you smoke? Have you had Covid`19 this year?  \
# 0               No                  Maybe (можливо)
# 1               No                              Yes
# 2               No                  Maybe (можливо)
# 3               No                               No
# 4               No                              Yes
# ...            ...                              ...
# 3303            No                  Maybe (можливо)
# 3304            No                  Maybe (можливо)
# 3305            No                  Maybe (можливо)
# 3306            No                  Maybe (можливо)
# 3307           Yes                              Yes
#
#                        IgM level                           IgG level  \
# 0     <0.9 (negative/негативний)  0.9-1.1 (indefinable/невизначений)
# 1     >1.1 (positive/позитивний)  0.9-1.1 (indefinable/невизначений)
# 2     <0.9 (negative/негативний)          <0.9 (negative/негативний)
# 3     <0.9 (negative/негативний)          <0.9 (negative/негативний)
# 4     >1.1 (positive/позитивний)          <0.9 (negative/негативний)
# ...                          ...                                 ...
# 3303                         NaN                                 NaN
# 3304                         NaN                                 NaN
# 3305                         NaN                                 NaN
# 3306                         NaN                                 NaN
# 3307  <0.9 (negative/негативний)          >1.1 (positive/позитивний)
#
#       Blood group Do you vaccinated influenza?  \
# 0             2.0                         True
# 1             2.0                        False
# 2             2.0                        False
# 3             2.0                        False
# 4             1.0                        False
# ...           ...                          ...
# 3303          2.0                         True
# 3304          2.0                         True
# 3305          1.0                        False
# 3306          2.0                        False
# 3307          2.0                        False
#
#      Do you vaccinated tuberculosis? Have you had influenza this year?  \
# 0                                Yes                                No
# 1                                Yes                                No
# 2                                Yes                               Yes
# 3                                Yes                                No
# 4                                Yes                               Yes
# ...                              ...                               ...
# 3303                             Yes                   Maybe (можливо)
# 3304                             Yes                   Maybe (можливо)
# 3305                             Yes                   Maybe (можливо)
# 3306                             Yes                   Maybe (можливо)
# 3307                             Yes                                No
#
#      Have you had tuberculosis this year?   Maximum body temperature
# 0                                       No                      38.1
# 1                                       No                      37.0
# 2                                       No                      37.8
# 3                                       No                       NaN
# 4                                       No                      37.4
# ...                                    ...                       ...
# 3303                                    No                      37.3
# 3304                                    No                      37.4
# 3305                                    No                      37.7
# 3306                                    No                      38.0
# 3307                                    No                      37.4
#
# [3297 rows x 14 columns]

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3297 entries, 0 to 3307
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date time                              3297 non-null   datetime64[ns]
#  1   Age                                    3296 non-null   object
#  2   Gender                                 3297 non-null   object
#  3   Region                                 3279 non-null   object
#  4   Do you smoke?                          3267 non-null   object
#  5   Have you had Covid`19 this year?       3296 non-null   object
#  6   IgM level                              3221 non-null   object
#  7   IgG level                              3237 non-null   object
#  8   Blood group                            3243 non-null   float64
#  9   Do you vaccinated influenza?           3190 non-null   object
#  10  Do you vaccinated tuberculosis?        3294 non-null   object
#  11  Have you had influenza this year?      3290 non-null   object
#  12  Have you had tuberculosis this year?   3290 non-null   object
#  13  Maximum body temperature               1529 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(11)
# memory usage: 386.4+ KB

# %%
c = 'Age'
df.loc[:, c] = df[c].astype('category')

# %%
df['Age']
# Out:
# 0       40-65
# 1       23-40
# 2       23-40
# 3       40-65
# 4       16-22
#         ...
# 3303    40-65
# 3304    40-65
# 3305    40-65
# 3306    40-65
# 3307    16-22
# Name: Age, Length: 3297, dtype: object

# %%
for c in df.columns[1:-1]:
  df.loc[:, c] = df[c].apply(lambda x : str(x) if str(x).find('(') == -1 else str(x)[:str(x).find('(')]). astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3297 entries, 0 to 3307
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date time                              3297 non-null   datetime64[ns]
#  1   Age                                    3297 non-null   object
#  2   Gender                                 3297 non-null   object
#  3   Region                                 3297 non-null   object
#  4   Do you smoke?                          3297 non-null   object
#  5   Have you had Covid`19 this year?       3297 non-null   object
#  6   IgM level                              3297 non-null   object
#  7   IgG level                              3297 non-null   object
#  8   Blood group                            3297 non-null   category
#  9   Do you vaccinated influenza?           3297 non-null   object
#  10  Do you vaccinated tuberculosis?        3297 non-null   object
#  11  Have you had influenza this year?      3297 non-null   object
#  12  Have you had tuberculosis this year?   3297 non-null   object
#  13  Maximum body temperature               1529 non-null   float64
# dtypes: category(1), datetime64[ns](1), float64(1), object(11)
# memory usage: 364.0+ KB

# %%
df. describe()
# Out:
#                            Date time  Maximum body temperature
# count                           3297               1529.000000
# mean   2020-12-10 19:29:52.464443136                 37.710203
# min              2020-09-20 11:23:15                 36.600000
# 25%    2020-12-17 23:14:18.347000064                 37.200000
# 50%    2020-12-24 13:39:36.980999936                 37.700000
# 75%    2020-12-28 16:22:47.089999872                 38.300000
# max       2021-04-05 03:18:16.644000                 38.800000
# std                              NaN                  0.634367

# %%
df.describe(include=['category'])
# Out:
#        Blood group
# count         3297
# unique           5
# top            2.0
# freq          1381

# %%
df['Age'].value_counts()
# Out:
# Age
# 23-40    1174
# 40-65    1063
# 16-22     823
# >65       193
# 0-15       43
# nan         1
# Name: count, dtype: int64

# %%
df['Age'].value_counts(normalize=True)
# Out:
# Age
# 23-40    0.356081
# 40-65    0.322414
# 16-22    0.249621
# >65      0.058538
# 0-15     0.013042
# nan      0.000303
# Name: proportion, dtype: float64

# %%
df.sort_values(by='Age',
        ascending=True)
# Out:
#                    Date time   Age   Gender          Region Do you smoke?  \
# 825  2020-12-17 23:09:15.156  0-15  Female   Ukraine, Lviv             No
# 198  2020-09-26 11:19:25.000  0-15    Male   Ukraine, Lviv             No
# 2501 2020-12-28 16:27:57.830  0-15    Male   Ukraine, Lviv             No
# 779  2020-12-17 19:19:43.744  0-15  Female   Ukraine, Lviv             No
# 778  2020-12-17 19:19:43.744  0-15  Female   Ukraine, Lviv             No
# ...                      ...   ...      ...             ...           ...
# 1939 2020-12-27 16:02:02.363   >65  Female   Ukraine, Lviv             No
# 1708 2020-12-24 14:17:23.874   >65  Female   Ukraine, Lviv             No
# 1121 2020-12-19 01:12:52.059   >65    Male   Ukraine, Lviv            Yes
# 671  2020-11-19 20:41:08.725   >65    Male   Ukraine, Lviv            Yes
# 3256 2021-01-14 09:50:55.735   nan  Female   Ukraine, Lviv             No
#
#      Have you had Covid`19 this year? IgM level IgG level Blood group  \
# 825                                No     <0.9      <0.9          2.0
# 198                                No     <0.9      <0.9          4.0
# 2501                              Yes     <0.9      >1.1          3.0
# 779                                No     <0.9      <0.9          2.0
# 778                                No     <0.9      <0.9          2.0
# ...                               ...       ...       ...         ...
# 1939                              Yes  0.9-1.1      >1.1          1.0
# 1708                              Yes     >1.1      <0.9          1.0
# 1121                               No     <0.9      <0.9          1.0
# 671                               Yes     <0.9      >1.1          1.0
# 3256                              Yes     >1.1      >1.1          2.0
#
#      Do you vaccinated influenza? Do you vaccinated tuberculosis?  \
# 825                         False                             Yes
# 198                         False                              No
# 2501                        False                             Yes
# 779                         False                          Maybe
# 778                         False                          Maybe
# ...                           ...                             ...
# 1939                        False                             Yes
# 1708                         True                             Yes
# 1121                        False                          Maybe
# 671                         False                             Yes
# 3256                        False                             Yes
#
#      Have you had influenza this year? Have you had tuberculosis this year?   \
# 825                                 No                                    No
# 198                                Yes                                    No
# 2501                                No                                    No
# 779                             Maybe                                     No
# 778                             Maybe                                     No
# ...                                ...                                   ...
# 1939                                No                                    No
# 1708                               Yes                                    No
# 1121                                No                                    No
# 671                                 No                                    No
# 3256                               nan                                    No
#
#       Maximum body temperature
# 825                        NaN
# 198                        NaN
# 2501                      37.5
# 779                        NaN
# 778                        NaN
# ...                        ...
# 1939                      36.6
# 1708                      36.7
# 1121                       NaN
# 671                       37.7
# 3256                      38.0
#
# [3297 rows x 14 columns]

# %%
df.sort_values(by=['Age', 'Gender'], ascending=[True, False]),
# Out:
# (                   Date time   Age   Gender          Region Do you smoke?  \
#  39   2020-09-20 11:26:09.000  0-15    Male   Ukraine, Lviv             No
#  198  2020-09-26 11:19:25.000  0-15    Male   Ukraine, Lviv             No
#  216  2020-09-26 11:42:15.000  0-15    Male   Ukraine, Lviv             No
#  296  2020-10-09 19:35:56.393  0-15    Male   Ukraine, Lviv             No
#  687  2020-11-24 10:55:41.181  0-15    Male   Ukraine, Lviv             No
#  ...                      ...   ...      ...             ...           ...
#  3258 2021-01-14 09:53:02.056   >65  Female   Ukraine, Lviv             No
#  3285 2021-02-16 10:08:13.109   >65  Female   Ukraine, Lviv             No
#  3296 2021-02-25 11:45:59.137   >65  Female   Ukraine, Lviv             No
#  3301 2021-03-02 09:53:11.825   >65  Female   Ukraine, Lviv             No
#  3256 2021-01-14 09:50:55.735   nan  Female   Ukraine, Lviv             No
#
#       Have you had Covid`19 this year? IgM level IgG level Blood group  \
#  39                                 No     <0.9      <0.9          2.0
#  198                                No     <0.9      <0.9          4.0
#  216                            Maybe      <0.9   0.9-1.1          1.0
#  296                                No     <0.9      <0.9          4.0
#  687                                No     <0.9   0.9-1.1          1.0
#  ...                               ...       ...       ...         ...
#  3258                               No       nan       nan         2.0
#  3285                           Maybe        nan       nan         nan
#  3296                              Yes       nan       nan         nan
#  3301                           Maybe        nan       nan         2.0
#  3256                              Yes     >1.1      >1.1          2.0
#
#       Do you vaccinated influenza? Do you vaccinated tuberculosis?  \
#  39                          False                             Yes
#  198                         False                              No
#  216                         False                             Yes
#  296                         False                              No
#  687                         False                             Yes
#  ...                           ...                             ...
#  3258                        False                             Yes
#  3285                        False                             Yes
#  3296                         True                             Yes
#  3301                         True                             Yes
#  3256                        False                             Yes
#
#       Have you had influenza this year? Have you had tuberculosis this year?   \
#  39                                  No                                    No
#  198                                Yes                                    No
#  216                             Maybe                                     No
#  296                                Yes                                    No
#  687                                 No                                    No
#  ...                                ...                                   ...
#  3258                                No                                    No
#  3285                                No                                   Yes
#  3296                                No                                    No
#  3301                            Maybe                                     No
#  3256                               nan                                    No
#
#        Maximum body temperature
#  39                         NaN
#  198                        NaN
#  216                       38.7
#  296                        NaN
#  687                        NaN
#  ...                        ...
#  3258                       NaN
#  3285                      37.6
#  3296                      36.8
#  3301                      37.0
#  3256                      38.0
#
#  [3297 rows x 14 columns],)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female     1818
# Male       1479
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().keys()
# Out:
# Index(['Female ', 'Male '], dtype='object', name='Gender')

# %%
df[df['Gender'] == 'Female ']['Maximum body temperature'].mean()
# Out:
# np.float64(37.706805293005665)

# %%
df[(df['Gender'] == 'Male ') & (df['Do you smoke?'] == 'Yes') & (df['Have you had Covid`19 this year?'] == 'Yes')] ['Maximum body temperature'].max()
# Out:
# 38.8

# %%
df.groupby(['Gender'])['Maximum body temperature'].describe()
# Out:
#           count       mean       std   min   25%   50%   75%   max
# Gender
# Female   1058.0  37.706805  0.625076  36.6  37.2  37.7  38.2  38.8
# Male      471.0  37.717834  0.655371  36.6  37.1  37.7  38.3  38.8

# %%
pd.crosstab(df['Age'], df['Gender'])
# Out:
# Gender  Female   Male
# Age
# 0-15         15     28
# 16-22       266    557
# 23-40       645    529
# 40-65       795    268
# >65          96     97
# nan           1      0

# %%
pd.pivot_table(df, values= 'Maximum body temperature', index= ['Age'], columns=['Gender'], aggfunc='mean', margins=True)
# Out:
# Gender    Female       Male         All
# Age
# 0-15    38.500000  37.437500  37.555556
# 16-22   37.731579  37.790196  37.746305
# 23-40   37.759053  37.754680  37.757473
# 40-65   37.679435  37.690780  37.681947
# >65     37.502041  37.642647  37.583761
# nan     38.000000        NaN  38.000000
# All     37.706805  37.717834  37.710203

# %%
sns.countplot(x='Age', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
_, axes = plt.subplots(1, 2, sharey=True, figsize=(16,6))

df_t = df[df['Have you had Covid`19 this year?'] == 'Yes'].dropna(subset=['Maximum body temperature'])
sns.distplot(df_t['Maximum body temperature'], ax=axes[0])
df_t = df[df['Have you had Covid`19 this year?'] == 'Maybe'].dropna(subset=['Maximum body temperature'])
sns.distplot(df_t['Maximum body temperature'], ax=axes[1])
# Out:
# <Axes: xlabel='Maximum body temperature', ylabel='Density'>

# %%
cols = ['Maximum body temperature', 'Maximum body temperature']
_, axes = plt.subplots(1, 2, sharey=True, figsize=(16,6))
sns.boxplot(y = df["Age"], x=df["Maximum body temperature"], ax=axes[0])
sns.violinplot(y = df["Age"], x=df["Maximum body temperature"],ax=axes[1] )
# Out:
# <Axes: xlabel='Maximum body temperature', ylabel='Age'>
